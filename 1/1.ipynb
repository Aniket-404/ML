# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
wine_dataset = pd.read_csv("winequalityN.csv")
wine_dataset.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
wine_dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6488.000000  6493.000000  6497.000000  6497.000000
# mean      3.218395     0.531215    10.491801     5.818378
# std       0.160748     0.148814     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
# Check for missing values
print("Missing values in dataframe:")
print(wine_dataset.isnull().sum())
# Out:
# Missing values in dataframe:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
# Drop rows with missing values
wine_dataset = wine_dataset.dropna()
wine_dataset
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6491    red            6.8             0.620         0.08             1.9
# 6492    red            6.2             0.600         0.08             2.0
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6491      0.068                 28.0                  38.0  0.99651  3.42
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6491       0.82      9.5        6
# 6492       0.58     10.5        5
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6463 rows x 13 columns]

# %%
X = wine_dataset.drop('type', axis=1)
Y = wine_dataset['type']

# %%
# Initialize the StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(X)

# %%
# Apply PCA
pca = PCA(n_components=2) # specify the number of principal components you want
principal_components = pca.fit_transform(scaled_data)

# %%
# Create a dataframe for the principal components
principal_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'])

# %%
# Concatenate the principal components with the original dataframe
final_df = pd.concat([principal_df, wine_dataset], axis=1)
final_df
# Out:
#            PC1       PC2   type  fixed acidity  volatile acidity  citric acid  \
# 0     2.498369  3.164667  white            7.0             0.270         0.36
# 1    -0.082698 -0.473924  white            6.3             0.300         0.34
# 2     0.183039  0.291706  white            8.1             0.280         0.40
# 3     1.751396  0.733701  white            7.2             0.230         0.32
# 4     1.751396  0.733701  white            7.2             0.230         0.32
# ...        ...       ...    ...            ...               ...          ...
# 6491       NaN       NaN    red            6.8             0.620         0.08
# 6492       NaN       NaN    red            6.2             0.600         0.08
# 6494       NaN       NaN    red            6.3             0.510         0.13
# 6495       NaN       NaN    red            5.9             0.645         0.12
# 6496       NaN       NaN    red            6.0             0.310         0.47
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0               20.7      0.045                 45.0                 170.0
# 1                1.6      0.049                 14.0                 132.0
# 2                6.9      0.050                 30.0                  97.0
# 3                8.5      0.058                 47.0                 186.0
# 4                8.5      0.058                 47.0                 186.0
# ...              ...        ...                  ...                   ...
# 6491             1.9      0.068                 28.0                  38.0
# 6492             2.0      0.090                 32.0                  44.0
# 6494             2.3      0.076                 29.0                  40.0
# 6495             2.0      0.075                 32.0                  44.0
# 6496             3.6      0.067                 18.0                  42.0
#
#       density    pH  sulphates  alcohol  quality
# 0     1.00100  3.00       0.45      8.8      6.0
# 1     0.99400  3.30       0.49      9.5      6.0
# 2     0.99510  3.26       0.44     10.1      6.0
# 3     0.99560  3.19       0.40      9.9      6.0
# 4     0.99560  3.19       0.40      9.9      6.0
# ...       ...   ...        ...      ...      ...
# 6491  0.99651  3.42       0.82      9.5      6.0
# 6492  0.99490  3.45       0.58     10.5      5.0
# 6494  0.99574  3.42       0.75     11.0      6.0
# 6495  0.99547  3.57       0.71     10.2      5.0
# 6496  0.99549  3.39       0.66     11.0      6.0
#
# [6495 rows x 15 columns]

# %%
# Scatter plot of PC1 vs PC2, colored by wine type
plt.figure(figsize=(10, 6))
sns.scatterplot(data=final_df, x='PC1', y='PC2', hue='type', palette={'red': 'red', 'white': 'blue'})
plt.title('PCA of Wine Dataset')
plt.xlabel('Principal Component 1 (PC1)')
plt.ylabel('Principal Component 2 (PC2)')
plt.legend(title='Wine Type')
plt.show()
